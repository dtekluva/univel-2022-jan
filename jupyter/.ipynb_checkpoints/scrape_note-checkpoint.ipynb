# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages (2.26.0)
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\inyang\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages (from requests) (2.0.7)

# %%
import bs4 
import requests
import datetime, re
import urllib.request

# %%
soup = bs4.BeautifulSoup

# %%
response = requests.get("https://hub360.com.ng/")

# %%
categories = soup(response.text).find("ul", {"id":"category-menu"})

# %%
for category in categories.find_all("li"):
    
    print(category.find("a").attrs["href"])
    link = category.find("a").attrs["href"]
    
    for i in range(1,5):
        response = requests.get(f"{link}page/{i}/")
        products = soup(response.text).find_all("div", {"class":"product-block"})

        for product in products:
            data = product.find("h3", {"class":"name"})
            link = data.find("a").attrs["href"]
            response = requests.get(link)
            single_products = soup(response.text)
            name = single_products.find("h1", {"class":"product_title entry-title"}).text
            img  = single_products.find("div", {"class":"image-mains"}).find("img").attrs["data-large_image"]
            
            name = re.sub('[^A-Za-z0-9]+', ' ', name)
            
            urllib.request.urlretrieve(img, f"{name}.png".replace("*", "x").replace("/", "-"))

            description = single_products.find("div", {"class":"woocommerce-Tabs-panel woocommerce-Tabs-panel--description panel entry-content wc-tab"}).text
            price = single_products.find("bdi").text
            file_name = name.replace("*", "x").replace("/", "-")
            
            with open(f"{name}.txt", "w", encoding='cp850', errors='replace') as description_file:
                
                description_file.write(f"{name}\n\n{price}\n{description}")

                
            print(name, img, price, description, sep="\n")
# Out:
# https://hub360.com.ng/product-category/accessorie/
# Male male jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-3-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# 20w hot glue stick
# https://hub360.com.ng/wp-content/uploads/2017/03/23-1.jpg
# ₦0.00
#
# This Glue Sticks are created with safe and reliable materials which are great for projects, arts and crafts, designing and DIYs. Application for paper, metal, wood, glass, card, fabric, plastic, ceramics and more. It works perfectly on low or high temperature glue guns and always dry clear and secure
#
# Male female jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-2-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# Male female jumper wire set
# https://hub360.com.ng/wp-content/uploads/2018/02/1-4-1.jpg
# ₦0.00
#
# This is a set of 40 connected male-female dupont jumper wires. The wires can all be used together or easily peeled apart individually or in sections.
#
# Hot glue sticks 60w
# https://hub360.com.ng/wp-content/uploads/2017/03/1.jp_2-1.jpg
# ₦0.00
#
# Standard clear multi temp, all-purpose adhesive bonds many plastics, wood products, fabric, leather, foam, PVC, poly-carbonate, paper, ribbon and aluminum. Low temp gun to bond more delicate materials such as foam, fabric or floral. High temp gun to bond less porous materials such as wood, glass and metal. 11 mm  (7/16″)- 12″ long
#
# Neodymium super magnet 8x5mm
# https://hub360.com.ng/wp-content/uploads/2018/11/magnet.jpg
# ₦0.00
#
# This Rare Earth Neodymium Magnets round super magnet is an add on to your maker inventory, so unleash your creativity and have fun!
# it has common usage like: Fridge magnets, Whiteboard magnets, DIY, map magnets,Hang key, Science projects, office magnets, Art and crafts, Organize to-do lists and many more
#
#
#
#
# Female female jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-1.jpeg
# ₦0.00
#
# This is a single piece female-female jumper wires.
#
# Tact switch 12 12 6
# https://hub360.com.ng/wp-content/uploads/2017/08/18-1.jpg
# ₦0.00
#
# This is a standard 12mm square momentary button. Its got a large button head and good tactile feel . This button is great for user input on a PCB or a good, big reset button on a breadboard.
#
# Female female jumper wire set
# https://hub360.com.ng/wp-content/uploads/2018/02/1-1-1.jpg
# ₦0.00
#
# This is a set of 40 connected female-female dupont jumper wires. The wires can all be used together or easily peeled apart individually or in sections.
#
# Professional soldering iron stand
# https://hub360.com.ng/wp-content/uploads/2016/10/21-2.jpg
# ₦0.00
#
# This is a simple soldering iron stand composed of a heavy-duty metal base and a reinforced spring holder. The base and holder are detachable. A soldering iron stand is used to keep the hot soldering iron away from you and the work area. A soldering iron stand is made out of metal.
#
# Condenser mic 4 5 2 2mm microphone
# https://hub360.com.ng/wp-content/uploads/2015/01/Electret-condenser-microphone-1.jpg
# ₦0.00
#
# This is a parallel plate capacitor and works on the principle of a variable capacitance. It consists of two plates, one fixed (called the back plate) and the other moveable (called Diaphragm) with a small gap between them. An electric potential charges the plate. When sound strikes the diaphragm it starts moving, thereby changing the capacitance between the plates which in turn results in a variable electric current to flow.
#
# sg90 servo
# https://hub360.com.ng/wp-content/uploads/2015/01/437144083_782-1.jpg
# ₦0.00
#
#  technical data:
# Size: 21.5 mmX11.8 mmX22.7 mm
# 9 grams of weight:
# No-load speed: 0.12 seconds / 60 degrees (4.8 V)
# Locked-rotor torque: 1.2-1.4 kg/cm (4.8 V)
# Use the temperature: – 30 ~ ~ + 60 degrees Celsius
# Dead zone setting: seven microseconds
# Operating voltage: 4.8 V to 6 V
# Contains: steering gear, rocker arm, screws, etc. All original accessories
#
# 14uH 43mm high current wireless power coil XKT L3
# https://hub360.com.ng/wp-content/uploads/2015/01/XKT-L3.jpg
# ₦0.00
#
# Parameters: the line diameter 1.1mm, the outer diameter 43mm, the inner diameter 20mm single layer thickness 2.3mm, can be applied to the XKT-412 chip.
# Working current 2000mA, this coil is mainly used in wireless charging scheme, this coil is a standard machine.
#
#
#
# SD card Module
# https://hub360.com.ng/wp-content/uploads/2015/01/F6VF1OJH5ENQ08B.LARGE_-1.jpg
# ₦0.00
#
# This SD Card module can make your SD application easier and simple.
# It is easily interfaced as a peripheral to your Arduino sensor shield module.
# Through programming, you can read and write to the SD card using your Arduino.
# Can be used for SD Card more easily, such as for MP3 Player, MCU/ARM system control.
# All SD SPI pins output, MOSI, SCK, MISO and CS.
# Support 5V/3.3V input
# Material: Metal
# Size: Approx. 5 x 3 x 1cm (L*W*H)
#
# L298N Dual H Bridge DC Stepper Motor Driver
# https://hub360.com.ng/wp-content/uploads/2015/01/L298StepperController__79861.1411263026.1280.1280-1.jpg
# ₦0.00
#
# Basic attributes
# Module name :Dual H-bridge motor driver module
# Operating mode :H-bridge driver (dual)
# Master chip :L298N
# Logic voltage :5V
# Drive voltage :5V-35V
# Logic Current :0mA-36mA
# Drive current :2A (MAX single bridge)
# Storage Temperature :-20 to 135
# Maximum Power :25W
# Weight :30g
# External dimensions :43 * 43 * 27mm
#
# Raspberry pi 3 transparent injection case
# https://hub360.com.ng/wp-content/uploads/2016/02/1-3.jpg
# ₦0.00
#
# Features:
# Tested on the  Raspberry Pi 2 Model B
# Easy GPIO ‘Cut-Out’ access (for anyone wanting to use a break-out board)
# Two-part Raspberry Pi case with pinch locking/unlocking
# Snap-fit mounting holds the Pi securely
# Access to all Pi connectors incl: Power, Video/Audio, USB, LAN, microSD card, GPIO
# Air vents for keeping Raspberry Pi cool
# 9.5cmx6.2cmx2.7cm
# No screws or assembly required
# Wall Mount Feature
# Raspberry Pi 2 Model B not included
#
# Material:
# The case is made of ABS material.
# Dimension: 9.5cmx6.2cmx2.7cm
#
# Arduino 9V battery connector
# https://hub360.com.ng/wp-content/uploads/2015/01/2234444260_8d5d32326f-1.jpg
# ₦0.00
#
# You can power your Arduino board through the USB connection, or through an external power supply with a 2.1mm center positive barrel jack. A 9V battery is a great way to power your Arduino board when USB power is not enough – i.e., when you use any kind of motor, or many LEDs simultaneously.
#
# Photoresistor LDR
# https://hub360.com.ng/wp-content/uploads/2015/01/Photoresistor-1.jpg
# ₦0.00
#
# The maximum voltage (V-dc): 150
# Maximum power (mW): 100
# The environment temperature (° C): -30— +70
# The spectral peak (nm): 560
# Bright resistance (10Lux) (K): 5-10
# Dark resistance (M Ω): 0.8
# Response time (MS): the rise of: 30
# Drop: 30
# Illumination resistance characteristics: 2
#
# Raspberry Pi 4 Aluminum Case with Dual Cooling Fan Metal Shell
# https://hub360.com.ng/wp-content/uploads/2016/10/heat-sink-casing.jpg
# ₦0.00
#
# Please note that raspberry pi is not included
# Features:
#
# Ultra-thin design
# Easy to install
# Fast Heat dissipation
# Smooth and straight aluminum material
# All ports and slots of the case can match with Raspberry Pi 4 Computer Model B perfectly
# Open case design, you don’t need to worry it will effect wifi signal any more
# Reinforced aluminum material, lightweight and durable, long-lasting stainles
# We use silicon cooling pad (the thickness is only 0.5mm) to touch the shell body to dissipate heat. You can use the CPU grease to relace the silicon colling pad to get better heat dissipation.
#
#
# Dual Fan:
#
#  Noise: 18dB
#  Low Power Consumption Design
#  Dual Cooling Expericnce, More powerful heat dissipation
#  Very Quiet Cooling Fan, get rid of the fan noisy
#  All of the Fans were Tested by Our Engineer, Very Nice Quality Control
#  Update Thermal Tape Can Make Sure Best Heat Conduction Effect
#
#
# SMD tact switch with cap
# https://hub360.com.ng/wp-content/uploads/2016/02/IMG_1300-1-scaled.jpg
# ₦0.00
#
# This is a push button. It has four terminals
#
# Male female jumper wire set
# https://hub360.com.ng/wp-content/uploads/2018/02/1-4-1.jpg
# ₦0.00
#
# This is a set of 40 connected male-female dupont jumper wires. The wires can all be used together or easily peeled apart individually or in sections.
#
# sg90 servo
# https://hub360.com.ng/wp-content/uploads/2015/01/437144083_782-1.jpg
# ₦0.00
#
#  technical data:
# Size: 21.5 mmX11.8 mmX22.7 mm
# 9 grams of weight:
# No-load speed: 0.12 seconds / 60 degrees (4.8 V)
# Locked-rotor torque: 1.2-1.4 kg/cm (4.8 V)
# Use the temperature: – 30 ~ ~ + 60 degrees Celsius
# Dead zone setting: seven microseconds
# Operating voltage: 4.8 V to 6 V
# Contains: steering gear, rocker arm, screws, etc. All original accessories
# Tact switch
# https://hub360.com.ng/wp-content/uploads/2015/01/tact-switch-1.jpg
# ₦0.00
#
#
#
#
# Feature momentary contact, 4 pins, round black  push button, through hole mounting, 6 x 6 x 5mm size, etc.
# Used in the fields of electronic products,  household appliances and more.
# High precision mechanism design offers acute  operation and long service life. Specification
#
# Size: Approx.6x6x5mm
#
#
#
# Temperature: -25°~+-85°C
# Rated Load: DC12V 0.1A
# Contact Resistance: ≤ 0.03Ω
# Withstand Voltage: AC250 V (50Hz) /MIN
# Actuation Force: 1.3+-0.5N
# Insulation Resistance: ≥100MΩ
# Life:100000 times
#
#
#
#
# Male male jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-3-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# Raspberry pi 3 transparent injection case
# https://hub360.com.ng/wp-content/uploads/2016/02/1-3.jpg
# ₦0.00
#
# Features:
# Tested on the  Raspberry Pi 2 Model B
# Easy GPIO ‘Cut-Out’ access (for anyone wanting to use a break-out board)
# Two-part Raspberry Pi case with pinch locking/unlocking
# Snap-fit mounting holds the Pi securely
# Access to all Pi connectors incl: Power, Video/Audio, USB, LAN, microSD card, GPIO
# Air vents for keeping Raspberry Pi cool
# 9.5cmx6.2cmx2.7cm
# No screws or assembly required
# Wall Mount Feature
# Raspberry Pi 2 Model B not included
#
# Material:
# The case is made of ABS material.
# Dimension: 9.5cmx6.2cmx2.7cm
#
# 4 4 matrix keypad
# https://hub360.com.ng/wp-content/uploads/2015/01/HT16RnoFRVbXXagOFbX7-1.jpg
# ₦0.00
#
# Contact resistance of 500
# Insulation resistance 100M
# Key Operating Force 150-200N
# Rebound time 1 (ms)
# Life of 100 million (times)
# Operating Temperature 60
#
# 1, the electronic characteristics
# Circuit Rating: 35V (DC), 100mA, 1W
# Contact resistance: 10Ω ~ 500Ω
# (Varies according to the lead lengths and different from those of the material used)
# Insulation resistance: 100MΩ 100V
# Dielectric Strength: 250VRms (50 ~ 60Hz 1min)
# Electric shock jitter: <5ms
# Life span: tactile type: ≥ one million times
#
# 2, the mechanical properties
# Operating pressure: Touch feeling: 170 ~ 397g (6 ~ 14oz)
# Switch travel: touch-type: 0.6 ~ 1.5mm
#
# 3, the environment parameters
# Operating temperature: -40 to +80
# Storage temperature: -40 to +80
# Temperature: from 40,90% to 95%, 240 hours
# Vibration: 20G, max. (10 ~~ 200Hz, the Mil-SLD-202 M204.Condition B)
#
# Male male Jumper wires set
# https://hub360.com.ng/wp-content/uploads/2015/01/37894-1.jpg
# ₦0.00
#
# Keep them together, or split them apart – that’s the beauty of the 20cm (7-3/4″) 40-conductor ribbon jumper with male/female connectors. They behave like any other similar jumper, but these are in a super-convenient ribbon you can easily split apart into custom sets.
#
# https://hub360.com.ng/product-category/modules/
# HC SR04 UltraSonic Sensor
# https://hub360.com.ng/wp-content/uploads/2015/02/HC-SR04-lg-1-scaled.jpg
# ₦0.00
#
# HC-SR04 ultrasonic module can offer non-contact distance sensing function, the range of which is 2cm—400cm., and the range accuracy is up to 2mm; the module includes ultrasonic transmitter, receiver and control circuit.
# The basic operation principle is below:
# (1)use IO port TRIG to trigger ranging. It needs 10 us high level signal at least
# (2)Module can send 8 pro 40 kz square wave automatically, and will test if there is any signal returned.
# (3)If there is signal returned, output one high level signal via IO port ECHO. The duration of the high level signal is the time from transmitter to receiving with the ultrasonic.
# Testing distance =duration of high level*voice velocity(340m/s) / 2
# 2.Physical map
# Refer to the wiring diagram below,
# VCC supply 5V, and GND is ground wire. TRIG is trigger control signal input, ECHO is echo signal output.
#
# Blue LCD 1602
# https://hub360.com.ng/wp-content/uploads/2015/01/400px-I2C_LCD1602_TOY0046-1.jpg
# ₦0.00
#
# Blue and white
# Standard 16X2 LCD character module (backlit / blue)
# 1602 using a standard 16-pin interface, where:
# The first Foot : VSS is ground power
# Second Foot : VDD 5V positive power supply connection
# Third Foot: V0 end liquid crystal display contrast adjustment, contrast weakest connected to the positive supply, the highest contrast, will have a “ghosting” grounded power when the contrast is too high, you can adjust the contrast through a 10K potentiometer when using
# Fourth Foot: RS for register selection, select the data register is high, select the instruction register is low.
# Fifth  Foot : R / W signal line is read, the read operation is high, the write operation is low. When the RS and RW common is low can be written instructions or display address, when RS is low RW can be read busy signal is high, when RS is high RW is low, data can be written.
# Sixth  Foot: E terminal is enabled client, E Duanyou high jump when it becomes low, the LCD module executes the command.
# Seventh to fourteenth feet: D0 ~ D7 to eight bidirectional data line.
# Fifteenth  Foot: backlight power positive
# Sixteenth Foot: backlight power negative
#
# PIR motion sensor
# https://hub360.com.ng/wp-content/uploads/2015/01/pir_module-1.png
# ₦0.00
#
# Perfect version of HC-SR501 is based on infrared technology, automatic control module, imported from Germany LHI778 probe design, high sensitivity, reliability, ultra-low-voltage operation mode, widely used in various auto-sensing electrical equipment, especially the battery-powered automatic control products.
#
# Electrical parameters
# Product Type
#
# HC – SR501 human body sensing module
#
# Operating voltage range
#
# DC voltage 4.5-20V
#
# Quiescent Current
#
# <50uA
#
# Level Output
#
# High 3.3 V / Low 0V
#
# Trigger
#
# L unrepeatable trigger / H repeat trigger (default trigger repeat)
#
# Delay time
#
# 0.5-200S (adjustable) range can be made zero seconds – several minutes
#
# Blocking time
#
# 2.5S (default) can be made a few tenths range – tens
#
# PCB Dimensions
#
# 32mm * 24mm
#
# Induction angle
#
# <100 degree cone angle
#
# Working temperature
#
# -15- + 70 degrees
#
# Induction lens size
#
# Diameter: 23mm (default)
#
# Relay module 1 channel
# https://hub360.com.ng/wp-content/uploads/2015/02/1-channel.jpg
# ₦0.00
#
#
#
# Coil Voltage : DC 5V;
# load capacity : 10A 250Vac/125Vac/30Vdc/28Vdc
# material : plastic, metal
# Color : Blue;
#
#
# LM2596 Buck DC DC power module
# https://hub360.com.ng/wp-content/uploads/2016/03/189-1.jpg
# ₦0.00
#
#
# With voltage meter display; voltage meter error of ±0.1V; the range among 0~40V. (note: to ensure the voltage meter accuracy, please make sure that the input voltage is 4.2V or more).
# Voltage meter can be closed by long pressing button(minimum power loss).
# The range of input voltage is 4.2~40V and output voltage is1.25V~37V ,which are continuously adjustable.(The input voltage must 1V higher than output voltage)
# Maximum output current can be as high as 3A, but normal and stable working current is 2A.
# Use 150KHZ internal oscillation frequency, which is belong to the second generation of switch voltage regulator with low consumption and high efficiency.
#
#
# sim800L GSM module
# https://hub360.com.ng/wp-content/uploads/2016/02/13-1.jpg
# ₦0.00
#
# this sim800L connects easily with arduino and other MCUs because of its inbuilt regulator.
#
# Features:
# 100% High Quality
# Model: SIM800L
# Work voltage: 3.7~5V
# Network support: Quad-Band 850 / 900/ 1800 / 1900 MHz – would work on GSM networks in all countries across the world.
# TTL serial interface compatible with 3.3V and 5V MCU Microcontrollers,competible with arduino .
#
#
# L298N Dual H Bridge DC Stepper Motor Driver
# https://hub360.com.ng/wp-content/uploads/2015/01/L298StepperController__79861.1411263026.1280.1280-1.jpg
# ₦0.00
#
# Basic attributes
# Module name :Dual H-bridge motor driver module
# Operating mode :H-bridge driver (dual)
# Master chip :L298N
# Logic voltage :5V
# Drive voltage :5V-35V
# Logic Current :0mA-36mA
# Drive current :2A (MAX single bridge)
# Storage Temperature :-20 to 135
# Maximum Power :25W
# Weight :30g
# External dimensions :43 * 43 * 27mm
#
# DHT11 Temperature and humidity sensor
# https://hub360.com.ng/wp-content/uploads/2015/01/70487_digital_temp_humidity_sensor-1.jpg
# ₦0.00
#
# Digital Temperature Sensor & Humidity Sensor DHT11
# Humidity measuring range: 20% ~ 9 0% RH (0-50 ℃ temperature compensation)
# Temperature measuring range: 0 ~ +50 C ;
# Humidity measuring accuracy: 5.0% RH
# Temperature measurement accuracy: 2.0 C
# Response time: <5S
# Low power consumption
# Features
# single wire digital interface ( the most simple system integration, ultra-low prices )
# ultra-small size ( 12X15.5X5.5 mm )
# high reliability
# optimized long-term stability
# ESP8266 01S wifi module
# https://hub360.com.ng/wp-content/uploads/2015/02/1-1.jpg
# ₦0.00
#
# ESP8266 is a highly integrated chip designed for the needs of a new connected world. It offers a complete and self-contained Wi-Fi networking solution, allowing it to either host the application or to offload all Wi-Fi networking functions from another application processor.
#
# ESP8266 has powerful on-board processing and storage capabilities that allow it to be integrated with the sensors and other application specific devices through its GPIOs with minimal development up-front and minimal loading during runtime. Its high degree of on-chip integration allows for minimal external circuitry, and the entire solution, including front-end module, is designed to occupy minimal PCB area.
#
# Corresponding Interface:
#     SDIO 2.0, SPI, UART
#     32-pin QFN package
#     Integrated RF switch, balun, 24dBm PA, DCXO, and PMU
#     Integrated RISC processor, on-chip memory and external memory interfaces
#     Integrated MAC/baseband processors
#     Quality of Service management
#     I2S interface for high fidelity audio applications
#     On-chip low-dropout linear regulators for all internal supplies
#     Proprietary spurious-free clock generation architecture
#     Integrated WEP, TKIP, AES, and WAPI engines
#
# Specification:
#     802.11 b/g/n
#     Wi-Fi Direct (P2P), soft-AP
#     Integrated TCP/IP protocol stack
#     Integrated TR switch, balun, LNA, power amplifier and matching network
#     Integrated PLLs, regulators, DCXO and power management units
#     +19.5dBm output power in 802.11b mode
#     Power down leakage current of <10uA
#     Integrated low power 32-bit CPU could be used as application processor
#     SDIO 1.1/2.0, SPI, UART
#     STBC, 1×1 MIMO, 2×1 MIMO
#     A-MPDU & A-MSDU aggregation & 0.4ms guard interval
#     Wake up and transmit packets in < 2ms
#     Standby power consumption of < 1.0mW (DTIM3)
#
#
# Flame sensor
# https://hub360.com.ng/wp-content/uploads/2015/03/Flame-Sensor-Module1-1.jpg
# ₦0.00
#
#
#
#
# – Color: Blue
# – Material: PCB
# – Using LM393 comparator
# – Working voltage: 3.3~12V
# – Output format: 0 and 1 digit
# – Detection range: 760nm~1100nm
# – Detection angle: About 60 degrees, particularly sensitive to the flame spectrum
# – Adjustable sensitivity (potentiometer adjustment)
# – The comparator output, the signal is clean, great driving ability, more than 15mA
# – With fixed bolt hole for easy installation
# – Can widely be used in Arduino DIY project
# – The flame sensor is most sensitive to flame, and reacts to ordinary light, is generally used in flame alarm etc.
# – The sensor and the flame should maintain a certain distance, in order to avoid high temperatures damage
#
#
#
#
#
#
# Dimensions: 1.89 in x 0.55 in x 0.28 in (4.8 cm x 1.4 cm x 0.7 cm)
# Weight: 0.18 oz (5 g)
#
#
#
#
#
# RF transmitters and receivers
# https://hub360.com.ng/wp-content/uploads/2015/01/rf-1.jpg
# ₦0.00
#
# TX Technical Specifications:
#
#  Working voltage: 3V12V
# Working current: max40mA (12V), min9mA(3V)
# Resonance mode: sound wave resonance (SAW)
# Modulation mode: ASK /OOK
# Working frequency: 315MHz-433.92MHz, customized frequency is available
# Transmission power: 25mW (315MHz at 12V)
# Frequency error: +150kHz (max)
#  Velocity: 10Kbps
# Self-owned codes: negative
#
# RX Technical Specifications:
#
# Working voltage: 5.0VDC +0.5V
# Working current:5.5mA (5.0VDC)
#  Working principle: single chip superregeneration receiving
# Working method: OOK/ASK
# Working frequency: 315MHz-433.92MHz, customized frequency is available
# Bandwidth: 2MHz (315MHz, having result from testing at lowing the sensitivity 3dBm)
# Sensitivity: excel -100dBm (50)
# Transmitting velocity: <9.6Kbps (at 315MHz and -95dBm)
#
#
# PIR motion sensor
# https://hub360.com.ng/wp-content/uploads/2015/01/pir_module-1.png
# ₦0.00
#
# Perfect version of HC-SR501 is based on infrared technology, automatic control module, imported from Germany LHI778 probe design, high sensitivity, reliability, ultra-low-voltage operation mode, widely used in various auto-sensing electrical equipment, especially the battery-powered automatic control products.
#
# Electrical parameters
# Product Type
#
# HC – SR501 human body sensing module
#
# Operating voltage range
#
# DC voltage 4.5-20V
#
# Quiescent Current
#
# <50uA
#
# Level Output
#
# High 3.3 V / Low 0V
#
# Trigger
#
# L unrepeatable trigger / H repeat trigger (default trigger repeat)
#
# Delay time
#
# 0.5-200S (adjustable) range can be made zero seconds – several minutes
#
# Blocking time
#
# 2.5S (default) can be made a few tenths range – tens
#
# PCB Dimensions
#
# 32mm * 24mm
#
# Induction angle
#
# <100 degree cone angle
#
# Working temperature
#
# -15- + 70 degrees
#
# Induction lens size
#
# Diameter: 23mm (default)
#
# Ethernet Network Board Module ENC28J60
# https://hub360.com.ng/wp-content/uploads/2015/03/ENC28j60EthernetInterfaceModule1_1391867612-1.jpg
# ₦0.00
#
# Description:
# ENC28J60-I/SO chip on board
# Onboard 25MHZ crystal
# Onboard HR911105A network interface
# 3.3V pin power supply
# Board size:56 (mm) x 34 (mm)
#
# 30cm Arduino nano cable
# https://hub360.com.ng/wp-content/uploads/2016/07/nano-cable.jpg
# ₦0.00
#
# Perfect fit for your Arduino Nano Boards.
# length:30CM/11.81 inch
# material:PVC
# colour:BLUE
#
# AS608 Optical fingerprint module
# https://hub360.com.ng/wp-content/uploads/2018/11/as698.jpg
# ₦0.00
#
# This module made fingerprint recognition more accessible and easy to add to your projects. This means that is is super easy to make fingerprint collection, registration, comparison and search.
# These modules come with FLASH memory to store the fingerprints and work with any microcontroller or system with TTL serial. These modules can be added to security systems, door locks, time attendance systems, and much more.
#
# RC522 RFID Module Kit
# https://hub360.com.ng/wp-content/uploads/2015/01/32365_1-1.jpg
# ₦0.00
#
# Package Included:
# 1 X RFID-RC522 module one;
# 1 X Standard S50 Blank Card;
# 1 X S50 shaped cards one (as shown keychain shape);
# 1 X Straight row pin
# 1 X Curved row pin
# Electrical parameters
# Working current: 13 26mA/ DC 3.3V
# Idle current: 10-13mA/ DC 3.3V
# Sleep current: <80uA
# The peak current: <30mA
# Operating frequency: 13.56MHz
# Card type: Mifare1 S50, Mifare1 support S70, Mifare UltraLight, Mifare Pro, Mifare Desfire
# Physical characteristics: size: 40mm x 60mm
# Environment temperature: -20 degrees Celsius 80 degrees
# Environmental storage temperature: -40 degrees Celsius 85 degrees
# Relative humidity: the relative humidity is 5% – 95%
#
# ACS712 current sensor 30A
# https://hub360.com.ng/wp-content/uploads/2015/05/12-1.jpg
# ₦0.00
#
# Description:
# 1, the current sensor chips: ACS712ELC-30A;
# 2, pin 30V power supply, on-board power indicator;
# 3, the module can measure the positive and negative 30 amps, corresponding to the analog output 100mV / A;
# 4, no test current through the output voltage is VCC / 2;
# 5, PCB board size: 31 (mm) x13 (mm);
# Note: ACS712 is based on the principle of the Hall test, please use this field to avoid impact
#
# Keyes Laser Diode
# https://hub360.com.ng/wp-content/uploads/2015/01/35-1.jpg
# ₦0.00
#
# 650nm Laser sensor Module 6mm 5V 5mW Red Laser Dot Diode Copper Head for Arduino
# Product Details:
#
# Laser sensor Module
# Operating voltage 5V
# Output wavelength 650 nm
# 3 pins module
# With fixed bolt hole for easy installation
#
#
#
# DHT11 Temperature and humidity sensor
# https://hub360.com.ng/wp-content/uploads/2015/01/70487_digital_temp_humidity_sensor-1.jpg
# ₦0.00
#
# Digital Temperature Sensor & Humidity Sensor DHT11
# Humidity measuring range: 20% ~ 9 0% RH (0-50 ℃ temperature compensation)
# Temperature measuring range: 0 ~ +50 C ;
# Humidity measuring accuracy: 5.0% RH
# Temperature measurement accuracy: 2.0 C
# Response time: <5S
# Low power consumption
# Features
# single wire digital interface ( the most simple system integration, ultra-low prices )
# ultra-small size ( 12X15.5X5.5 mm )
# high reliability
# optimized long-term stability
#
# Line Tracking Sensor
# https://hub360.com.ng/wp-content/uploads/2021/04/tracking2.jpeg
# ₦0.00
#
# The Line Tracking Sensor based on TCRT5000 is a type of infrared reflectance sensor, and is commonly used in line following robots, it is mounted at the bottom of the robot chassis. The line tracking sensor works by detecting reflected light coming from its own infrared LED and by measuring the amount of reflected infrared light, it can detect transitions from light to dark (lines) or even objects directly in front of it.
# Features :
#
# Sensor adopts TCRT5000, high sensitivity
# Sensitivity adjustable digital potentiometer to adjust (blue)
# Modules can induction block from 0 to 3 cm
# Working voltage 3.3 V to 5V
# Output analog voltage (0 to 5 v)
# Digital switch output (0 and 1)
# Has a fixed bolt hole, convenient installation
# Small board PCB size: 3.2 cm * 1.4 cm
# Power indicator light (red) and digital switch output indicator light (green)
# Comparator USES the LM393 chips, work stability
# Detection reflection distance: 1mm to 25mm
# Comparator output, signal waveform, driving ability is strong, for more than 15mA
# BMP180 Pressure Sensor
# https://hub360.com.ng/wp-content/uploads/2015/05/bmp180-1.jpg
# ₦0.00
#
# DESCRIPTION
#
# Size: 21mm x 18mm
# 1.8V to 6V Supply Voltage
# Max I2C Speed: 3.5Mhz
# Low power consumption – 0.5uA at 1Hz
# I2C interface
# Very low noise – up to 0.02hPa (17cm)
# Full calibrated
# Pressure Range: 300hPa to 1100hPa (+9000m to -500m)
#
#
#
# Anemometer wind speed 4 20mA 0 5V
# https://hub360.com.ng/wp-content/uploads/2020/05/anemometer.jpeg
# ₦0.00
#
# L-FS2  wind speed sensor (current/voltage type)
#
#
#
#
#
#
# Types of
# Cable outlet method
# Waterproof aviation plug type
#
#
#
# model
# JL-FS2
#
#
# name
# Universal wind speed sensor
#
#
#     sensor
# Signal output method
# Current type 4-20mA / Voltage type 0-5V
#
#
# Sensor style
# Three cups
#
#
# Starting wind speed
# Of 0. The 4-0.8 m / S
#
#
# Resolution
# 0.1m/s
#
#
# Effective wind speed measurement range
# 0-30m/s or  0-60 m/s
#
#
#    General parameters
# system error
# ± 3%
#
#
# Transmission distance
# More than 1000m
#
#
# Transmission medium
# Cable transmission
#
#
# Wiring
# Three-wire system
#
#
# Operating temperature
# -40℃ ~80 ℃
#
#
# Supply voltage
# DC12-24V can be universal
#
#
# Power consumption
# Voltage type MAX≤0.3W    ;        current type MAX≤0.7W
#
#
# size
# See size chart
#
#
# weight
# <1Kg
#
#
#
#
# Photoresistor LDR
# https://hub360.com.ng/wp-content/uploads/2015/01/Photoresistor-1.jpg
# ₦0.00
#
# The maximum voltage (V-dc): 150
# Maximum power (mW): 100
# The environment temperature (° C): -30— +70
# The spectral peak (nm): 560
# Bright resistance (10Lux) (K): 5-10
# Dark resistance (M Ω): 0.8
# Response time (MS): the rise of: 30
# Drop: 30
# Illumination resistance characteristics: 2
#
# Temperature Sensor LM35
# https://hub360.com.ng/wp-content/uploads/2015/01/LM35-1.jpg
# ₦0.00
#
# LM35 is an integrated circuit sensor that can be used to measure temperature with an electrical output proportional to the temperature in Celcius. Compared to thermistor, this component give more accurate result and generate higher voltage than thermocouples which may not require output amplifier.
# The scale factor for this sensor is .01V/oC and doesn’t require any external calibration or trimming and maintains an accuracy of +/-0.4 oC at room temperature and +/-0.8 oC over range of 0oC to 100 oC. It has three leg: VCC, V-out, GND. The VCC is input voltage to supply the IC. The V-out is the pin which output the result temperature reading.
#
# Hub360 Arduino kit
# https://hub360.com.ng/wp-content/uploads/2015/02/k1-1.png
# ₦0.00
#
# Developed an interest in electronics but have no idea where to start? Great news for you as the HUB360 ARDUINO STARTER KIT  is a great way for you to get started with embedded systems, micro controller programming, and electronics project prototyping! . Be  you an Electrical Electronics Engineering student,Computer scientist or just an hobbyist, this kit gives you an edge comparatively with its wide range of components and sensors. With about 250 components, the kit is very affordable and user friendly for both beginners and professionals.
# Below are the contents of the kit.
#
# 1 ARDUINO BOARD 1
# 2 ARDUINO USB CABLE 1
# 3 ARDUINO BATTERY CONNECTOR 1
# 4 BREADBOARD MB102 1
# 5 LED (RED, YELLOW , GREEN, WHITE) 20
# 6 RGB LED 2
# 7 JUMPER WIRE(M-M, M-F, F-F) 120
# 8 PHOTORESISTOR (LDR) 3
# 9 MALE HEADERS 40
# 10 ULTRASONIC SENSOR 1
# 11 FLAME SENSOR 1
# 12 TEMP./HUMIDITY SENSOR 1
# 13 TILT SENSOR 1
# 14 LASER SENSOR 1
# 15 PIR MOTION SENSOR 1
# 16 RESISTORS(220K, 1K, 10K,100K) 40
# 17 7 SEGMENT DISPLAY 1
# 18 SG90 SERVO 1
# 19 REMOTE CONTROL 1
# 20 BUZZER 1
# 21 2N2222 2
# 22 TSOP 1838 1
# 23 RF TRANSMITTER 1
# 24 RF RECEIVER 1
# 25 TACT SWITCH 5
# 26 16*2 LCD DISPLAY 1
#
#
# DHT11 Temperature and humidity sensor
# https://hub360.com.ng/wp-content/uploads/2015/01/70487_digital_temp_humidity_sensor-1.jpg
# ₦0.00
#
# Digital Temperature Sensor & Humidity Sensor DHT11
# Humidity measuring range: 20% ~ 9 0% RH (0-50 ℃ temperature compensation)
# Temperature measuring range: 0 ~ +50 C ;
# Humidity measuring accuracy: 5.0% RH
# Temperature measurement accuracy: 2.0 C
# Response time: <5S
# Low power consumption
# Features
# single wire digital interface ( the most simple system integration, ultra-low prices )
# ultra-small size ( 12X15.5X5.5 mm )
# high reliability
# optimized long-term stability
#
# ACS712 current sensor 30A
# https://hub360.com.ng/wp-content/uploads/2015/05/12-1.jpg
# ₦0.00
#
# Description:
# 1, the current sensor chips: ACS712ELC-30A;
# 2, pin 30V power supply, on-board power indicator;
# 3, the module can measure the positive and negative 30 amps, corresponding to the analog output 100mV / A;
# 4, no test current through the output voltage is VCC / 2;
# 5, PCB board size: 31 (mm) x13 (mm);
# Note: ACS712 is based on the principle of the Hall test, please use this field to avoid impact
#
# https://hub360.com.ng/product-category/board/
# Breadboard MB102
# https://hub360.com.ng/wp-content/uploads/2016/08/1-1.jpg
# ₦0.00
#
# This is is a construction base for prototyping of electronics before transferring to a permanent board
# Product Description:
# 1. Solderless Breadboard
# 2. 1 Terminal Strip
# 3.ABS plastic material
# 4. Completely reusable
# 5. Coloured coordinates for easy component placement
# 6. Phosphor bronze nickel plated spring clips
# 7. 830 holes altogether
#
# 200 Distribution Holes
# 630 Terminal Holes
#
# 8. Accepts a variety of wire sizes (29-20 AWG)
# 9. Dimensions: 54 x 166mm
#
# Hub360 Arduino kit
# https://hub360.com.ng/wp-content/uploads/2015/02/k1-1.png
# ₦0.00
#
# Developed an interest in electronics but have no idea where to start? Great news for you as the HUB360 ARDUINO STARTER KIT  is a great way for you to get started with embedded systems, micro controller programming, and electronics project prototyping! . Be  you an Electrical Electronics Engineering student,Computer scientist or just an hobbyist, this kit gives you an edge comparatively with its wide range of components and sensors. With about 250 components, the kit is very affordable and user friendly for both beginners and professionals.
# Below are the contents of the kit.
#
# 1 ARDUINO BOARD 1
# 2 ARDUINO USB CABLE 1
# 3 ARDUINO BATTERY CONNECTOR 1
# 4 BREADBOARD MB102 1
# 5 LED (RED, YELLOW , GREEN, WHITE) 20
# 6 RGB LED 2
# 7 JUMPER WIRE(M-M, M-F, F-F) 120
# 8 PHOTORESISTOR (LDR) 3
# 9 MALE HEADERS 40
# 10 ULTRASONIC SENSOR 1
# 11 FLAME SENSOR 1
# 12 TEMP./HUMIDITY SENSOR 1
# 13 TILT SENSOR 1
# 14 LASER SENSOR 1
# 15 PIR MOTION SENSOR 1
# 16 RESISTORS(220K, 1K, 10K,100K) 40
# 17 7 SEGMENT DISPLAY 1
# 18 SG90 SERVO 1
# 19 REMOTE CONTROL 1
# 20 BUZZER 1
# 21 2N2222 2
# 22 TSOP 1838 1
# 23 RF TRANSMITTER 1
# 24 RF RECEIVER 1
# 25 TACT SWITCH 5
# 26 16*2 LCD DISPLAY 1
#
#
# 400 hole mini breadboard
# https://hub360.com.ng/wp-content/uploads/2016/03/146-1.jpg
# ₦0.00
#
# This is is a construction base for prototyping of electronics before transferring to a permanent board
# Description:
# The 400 Tie Point Interlocking Solderless Breadboard is a cute half size breadboard, good for small projects.
# It is 8.2cm x 6.2cm in size with a standard double strip in the middle and two power rails on both sides.
# You can pull the power rails off easily to make the breadboard as thin as 3.5cm and stick it onto an
# protoshield. You can also cut these in half with a saw to create 2 tiny breadboards, or “snap”
# these breadboards together either way to make longer or wider breadboards.
# Specification:
# 400 Tie Point
# Self adhesive
# Can be interlocked for larger projects
# 2 power lanes
# Horizontal: 1-30
# Vertical: A-J
# Dimensions: 8.2cm x 6.2 cm
#
#
# vero board big size stripped
# https://hub360.com.ng/wp-content/uploads/2016/03/191-1.jpg
# ₦0.00
#
# This is a prototyping board, with copper pads. It is continuous from one point to another only in one direction. It has a lot of holes
#
#
# vero board small size stripped
# https://hub360.com.ng/wp-content/uploads/2016/03/192-1.jpg
# ₦0.00
#
# This is a prototyping board, with copper pads. It is continuous from one point to another only in one direction. It has a lot of holes
#
#
# vero board big size dotted
# https://hub360.com.ng/wp-content/uploads/2016/03/190-1.jpg
# ₦0.00
#
# This is a prototyping board, with copper pads. It is not continuous from one point to another You solder the components in place, and then simply cut pieces of wire, and solder them to make the circuit. It has a lot of holes
#
#
# Vero Board small size dotted
# https://hub360.com.ng/wp-content/uploads/2015/03/veroboard-1.jpg
# ₦0.00
#
# This is a prototyping board, with copper pads. It is not continuous from one point to another You solder the components in place, and then simply cut pieces of wire, and solder them to make the circuit. It has a lot of holes
# Arduino UNO R3 SMD
# https://hub360.com.ng/wp-content/uploads/2019/04/SMD-UNO_1.jpg
# ₦0.00
#
# This Uno R3 SMD, has most of the features of the Uno with the added benefit of an ISP header and CH340G interface. The UNO can be programmed over a USB B cable using the Arduino IDE: Just plug in the board, select “Arduino UNO” from the board menu and you are ready to upload sketches. You can power the UNO Board over USB or through the barrel jack. The on-board power regulator can handle anything from 7 to 15 Vdc.
#
# Technical Specifications:
#
# ATmega328P-AU microcontroller
# USB Programming Facilitated by the CH340G
# Header Pins Included.
# Input voltage – 7-15V
# 0-5V outputs with 3.3V compatible inputs
# 14 Digital I/O Pins (6 PWM outputs)
# 6 Analog Inputs
# ISP Header
# 32k Flash Memory
# 16MHz Clock Speed
# All SMD Construction
# R3 Shield Compatible
#
#
# TP4056 18650 1A lipo Battery Charger with Protection module
# https://hub360.com.ng/wp-content/uploads/2019/05/TP4056.jpg
# ₦0.00
#
#
#
#
# 5V 1A Micro USB 18650 Lithium Battery Charging Board Charger Module + Protection Dual Functions TP4056
#
# This is a miniature battery charger based on the TP4056 integrated circuit. It is ideal for adding an embedded battery charger to your new project.
# Charge Li-Ion batteries from onboard Micro USB connector from USB or external +5V source.
# With Micro-USB on board connector, you can directly connect to computer USB port for battery charging. If USB is not available you can use an external source voltage at IN+/IN- pads great for DIY projects
#
# Specifications
#
# Chipset: TP4056
# Input voltage: 4.5V~5.5V
# Fully charged voltage: 4.2V
# Charging current: 1A adjustable (Set originally to 1A)
# Working temperature: -10’C~85’C
# Charging method: Linear charging 1%
# Charging precision: 1.5%
# Charging indicator: Red light charging, Green light fully charged
# Interface: Micro USB
# Size : 25 x 19 x 10mm.
#
# Safety Notes:
#
# Ampere meter can only be connected to the 5v input end of the module.
# It is better that the charging current is 37% of the battery capacity. If you charge to the battery of 1000mAH, current of 400 is enough.
# The connection wire should not be too thick.
# Make sure the connection points is good.
# If the input voltage is too high, like 5.2v, the current will be less than 1000mA, it is normal. It is a protection function, auto-substract the charging current to avoid burn damage to chip.
# NO Reversal polarity.
#
#
#
#
# 3mm 8 8 dot matrix red led
# https://hub360.com.ng/wp-content/uploads/2015/05/1.20-inch-Green-Color-8-x-8-Dot-matrix-Display-1.jpg
# ₦0.00
#
# – LED Display Dot Matrix.
# – Common Anode,Red color,  8×8, 3mm, about 32x32mm,16pin.
# – 640nm, 10mcd.
#
# DF Mini MP3 player
# https://hub360.com.ng/wp-content/uploads/2018/05/ARD2809-1.jpg
# ₦0.00
#
# The DFPlayer Mini MP3 Player For Arduino is a small and low price MP3 module with an simplified output directly to the speaker. The module can be used as a stand alone module with attached battery, speaker and push buttons or used in combination with an Arduino UNO or any other with RX/TX capabilities.
#
# Arduino NANO expansion board
# https://hub360.com.ng/wp-content/uploads/2016/02/1-1-1.jpg
# ₦0.00
#
# Arduino Nano IO Expansion Shield is specifically designed to facilitate an easy connection between Arduino Nano and many other devices. In essence, it expands the Arduino Nano controller to link those devices in a simple and trouble free manner. It is a perfect companion of Nano breadboard and compatible with both Arduino Nano v2.x and v3.x.
# Specification
#
# Brand new and high quality.
# 14 I/O Pin (servo type with GND, power and signal).
# 8 analog Pin with power output and GND.
# 6 PWM Pin.
# 1 Servo power input.
# 5 I2C expansion Pin.
# AREF output.
# 3.3V output.
# Size: 5.7cm x 5.2cm x 1cm
#
#
#
# Relay timer with real time clock
# https://hub360.com.ng/wp-content/uploads/2017/09/timer-relay6.jpg
# ₦0.00
#
# Product Highlights:
# Wide voltage power supply 5.0V ~ 60V;
# A mode can be set for multiple time periods, can reach 5 time periods;
# With abuzzer alarm function.
# Mode introduction:
# OPE: relay closing time point, CLE: relay off time point
# Time period: PE-1 ~ PE-5 5 time periods (OPE to CLE is a time period)
# —-: function shielding
# P-1: The relay closes or outputs pulses every day to the OPE time point, and the relay turns off or outputs pulses to the CLE time point.
# P-2: set the day, to the OPE time point when the relay closed or output pulse, to the CLE time point when the relay disconnect / or output pulse
# P-3: set the date of the month, to the OPE time point when the relay closed or output pulse, to the CLE time point when the relay is off or output pulse
# P-4: Set the date 1 to date 2, start every day at the OPE time point, end to the CLE time point, relay action or output pulse
# P-5: As with P-4, only the month can not be set
# First, how to set the time?
#
# In the time to run the interface, press the DOWN button for a while:
# Step 1: Select the time period: PE-1 ~ PE-5 Press UP and DOWN to select;
# Step 2: Press the SET key to select the mode: P-1 ~ P-5 (Set this time period to the corresponding mode) by pressing the UP and DOWN keys. (“—-” means to block this time period)
# Note: Each time period can be repeated from the “—-“, P-1 ~ P-5 one of the optional; For example,you can let five time periods at the same time work in the P-1 mode, or let Time period 1 work in P-1 mode, time period 2 work in P-2 mode and so on.
# Step 3: After the mode selection is finished, press the SET key to enter the time period setting interface, set the interface in the time period, press the SET key to switch the parameter, “OPE” start time point, “CLE” end point, “dAE” date information;
# Step 4: After setting the parameters to exit the settings, press the SET button for 2 seconds to release, automatically check whether the parameter settings are legal, legal to save the parameters, return to the time to run the interface; if the parameter is wrong, “ERR” reminder (for example, stop timeor Date <= start timeor date), return to the parameter setting interface;
# Additional features: Each “time period” can be set individually
# In the specific parameter setting interface (after the second step), press the STOP button to switch the output mode:
# OUT1: Start time point turns on the relay, the end time is off the relay
# OUT2: Outputs 1S pulse to start or end time
# In the specific parameter setting interface (after the second step), press the STOP button for a while to switch the ringing mode:
# BLL0:Ringdisable
# BLL1: Ring enable
# Note: When the bell rings, press any button to stop the ring
#
# STOP key function expansion:
# Relay enable mode:
# 1. ON: enable relay on;
# 2. OFF: Do not turn on the relay, it is always off;
# Press the STOP button on the time display interface to switch between ON and OFF, the current status will flash, and then return to the main interface. (This function is the emergency stop function, press once to close the closed relay)
# After the relay is disabled, the product can be used as an alarm clock.
# Sleep mode:
#
#
# Hub360 Arduino kit
# https://hub360.com.ng/wp-content/uploads/2015/02/k1-1.png
# ₦0.00
#
# Developed an interest in electronics but have no idea where to start? Great news for you as the HUB360 ARDUINO STARTER KIT  is a great way for you to get started with embedded systems, micro controller programming, and electronics project prototyping! . Be  you an Electrical Electronics Engineering student,Computer scientist or just an hobbyist, this kit gives you an edge comparatively with its wide range of components and sensors. With about 250 components, the kit is very affordable and user friendly for both beginners and professionals.
# Below are the contents of the kit.
#
# 1 ARDUINO BOARD 1
# 2 ARDUINO USB CABLE 1
# 3 ARDUINO BATTERY CONNECTOR 1
# 4 BREADBOARD MB102 1
# 5 LED (RED, YELLOW , GREEN, WHITE) 20
# 6 RGB LED 2
# 7 JUMPER WIRE(M-M, M-F, F-F) 120
# 8 PHOTORESISTOR (LDR) 3
# 9 MALE HEADERS 40
# 10 ULTRASONIC SENSOR 1
# 11 FLAME SENSOR 1
# 12 TEMP./HUMIDITY SENSOR 1
# 13 TILT SENSOR 1
# 14 LASER SENSOR 1
# 15 PIR MOTION SENSOR 1
# 16 RESISTORS(220K, 1K, 10K,100K) 40
# 17 7 SEGMENT DISPLAY 1
# 18 SG90 SERVO 1
# 19 REMOTE CONTROL 1
# 20 BUZZER 1
# 21 2N2222 2
# 22 TSOP 1838 1
# 23 RF TRANSMITTER 1
# 24 RF RECEIVER 1
# 25 TACT SWITCH 5
# 26 16*2 LCD DISPLAY 1
#
#
# GY MAX30100 PURPLE
# https://hub360.com.ng/wp-content/uploads/2018/09/max30100.jpg
# ₦0.00
#
# It’s an optical sensor that derives its readings from emitting two wavelengths of light from two LEDs – a red and an infrared one – then measuring the absorbance of pulsing blood through a photo-detector.
# This particular LED color combination is optimized for reading the data through the tip of one’s finger.
# The signal is processed by a low-noise analog signal processing unit and communicated to the target MCU through the mikroBUS™ I2C interface.
# Developers of end-user applications should note that the readings can be negatively impacted by excess motion and changes in temperature. Also, too much pressure can constrict capillary blood flow and therefore diminish the reliability of the data. A programmable INT pin is also available.
# 4 4 matrix keypad
# https://hub360.com.ng/wp-content/uploads/2015/01/HT16RnoFRVbXXagOFbX7-1.jpg
# ₦0.00
#
# Contact resistance of 500
# Insulation resistance 100M
# Key Operating Force 150-200N
# Rebound time 1 (ms)
# Life of 100 million (times)
# Operating Temperature 60
#
# 1, the electronic characteristics
# Circuit Rating: 35V (DC), 100mA, 1W
# Contact resistance: 10Ω ~ 500Ω
# (Varies according to the lead lengths and different from those of the material used)
# Insulation resistance: 100MΩ 100V
# Dielectric Strength: 250VRms (50 ~ 60Hz 1min)
# Electric shock jitter: <5ms
# Life span: tactile type: ≥ one million times
#
# 2, the mechanical properties
# Operating pressure: Touch feeling: 170 ~ 397g (6 ~ 14oz)
# Switch travel: touch-type: 0.6 ~ 1.5mm
#
# 3, the environment parameters
# Operating temperature: -40 to +80
# Storage temperature: -40 to +80
# Temperature: from 40,90% to 95%, 240 hours
# Vibration: 20G, max. (10 ~~ 200Hz, the Mil-SLD-202 M204.Condition B)
#
# ESP8266 01S wifi module
# https://hub360.com.ng/wp-content/uploads/2015/02/1-1.jpg
# ₦0.00
#
# ESP8266 is a highly integrated chip designed for the needs of a new connected world. It offers a complete and self-contained Wi-Fi networking solution, allowing it to either host the application or to offload all Wi-Fi networking functions from another application processor.
#
# ESP8266 has powerful on-board processing and storage capabilities that allow it to be integrated with the sensors and other application specific devices through its GPIOs with minimal development up-front and minimal loading during runtime. Its high degree of on-chip integration allows for minimal external circuitry, and the entire solution, including front-end module, is designed to occupy minimal PCB area.
#
# Corresponding Interface:
#     SDIO 2.0, SPI, UART
#     32-pin QFN package
#     Integrated RF switch, balun, 24dBm PA, DCXO, and PMU
#     Integrated RISC processor, on-chip memory and external memory interfaces
#     Integrated MAC/baseband processors
#     Quality of Service management
#     I2S interface for high fidelity audio applications
#     On-chip low-dropout linear regulators for all internal supplies
#     Proprietary spurious-free clock generation architecture
#     Integrated WEP, TKIP, AES, and WAPI engines
#
# Specification:
#     802.11 b/g/n
#     Wi-Fi Direct (P2P), soft-AP
#     Integrated TCP/IP protocol stack
#     Integrated TR switch, balun, LNA, power amplifier and matching network
#     Integrated PLLs, regulators, DCXO and power management units
#     +19.5dBm output power in 802.11b mode
#     Power down leakage current of <10uA
#     Integrated low power 32-bit CPU could be used as application processor
#     SDIO 1.1/2.0, SPI, UART
#     STBC, 1×1 MIMO, 2×1 MIMO
#     A-MPDU & A-MSDU aggregation & 0.4ms guard interval
#     Wake up and transmit packets in < 2ms
#     Standby power consumption of < 1.0mW (DTIM3)
#
#
# 8 channel relay
# https://hub360.com.ng/wp-content/uploads/2015/01/8-2-750x750-1.png
# ₦0.00
#
# Size: 13.5 x 5.3 x 1.7cm (LxWxH)
# Working voltage: 5V
# Channel: 8 channel
# This relay module is 5V active low.
# It is an 8-channel relay interface board, which can be controlled directly by a wide range of microcontrollers such as Arduino, AVR, PIC, ARM, PLC, etc.
# It is also able to control various appliances and other equipments with large current.
# Relay output maximum contact is AC250V 10A and DC30V 10A.
# Standard interface can be directly connected with microcontrollers.
# Red working status indicator lights are conducive to the safe use.
# Widely used for all MCU control, industrial sector, PLC control, smart home control.
#
# AS608 Optical fingerprint module
# https://hub360.com.ng/wp-content/uploads/2018/11/as698.jpg
# ₦0.00
#
# This module made fingerprint recognition more accessible and easy to add to your projects. This means that is is super easy to make fingerprint collection, registration, comparison and search.
# These modules come with FLASH memory to store the fingerprints and work with any microcontroller or system with TTL serial. These modules can be added to security systems, door locks, time attendance systems, and much more.
#
# SD card Module
# https://hub360.com.ng/wp-content/uploads/2015/01/F6VF1OJH5ENQ08B.LARGE_-1.jpg
# ₦0.00
#
# This SD Card module can make your SD application easier and simple.
# It is easily interfaced as a peripheral to your Arduino sensor shield module.
# Through programming, you can read and write to the SD card using your Arduino.
# Can be used for SD Card more easily, such as for MP3 Player, MCU/ARM system control.
# All SD SPI pins output, MOSI, SCK, MISO and CS.
# Support 5V/3.3V input
# Material: Metal
# Size: Approx. 5 x 3 x 1cm (L*W*H)
#
# HC 05 bluetooth Module
# https://hub360.com.ng/wp-content/uploads/2015/03/hc-05-2.jpg
# ₦0.00
#
#
# ...
#
# Electrical parameters
# Product Type
#
# HC – SR501 human body sensing module
#
# Operating voltage range
#
# DC voltage 4.5-20V
#
# Quiescent Current
#
# <50uA
#
# Level Output
#
# High 3.3 V / Low 0V
#
# Trigger
#
# L unrepeatable trigger / H repeat trigger (default trigger repeat)
#
# Delay time
#
# 0.5-200S (adjustable) range can be made zero seconds – several minutes
#
# Blocking time
#
# 2.5S (default) can be made a few tenths range – tens
#
# PCB Dimensions
#
# 32mm * 24mm
#
# Induction angle
#
# <100 degree cone angle
#
# Working temperature
#
# -15- + 70 degrees
#
# Induction lens size
#
# Diameter: 23mm (default)
#
# Flame sensor
# https://hub360.com.ng/wp-content/uploads/2015/03/Flame-Sensor-Module1-1.jpg
# ₦0.00
#
#
#
#
# – Color: Blue
# – Material: PCB
# – Using LM393 comparator
# – Working voltage: 3.3~12V
# – Output format: 0 and 1 digit
# – Detection range: 760nm~1100nm
# – Detection angle: About 60 degrees, particularly sensitive to the flame spectrum
# – Adjustable sensitivity (potentiometer adjustment)
# – The comparator output, the signal is clean, great driving ability, more than 15mA
# – With fixed bolt hole for easy installation
# – Can widely be used in Arduino DIY project
# – The flame sensor is most sensitive to flame, and reacts to ordinary light, is generally used in flame alarm etc.
# – The sensor and the flame should maintain a certain distance, in order to avoid high temperatures damage
#
#
#
#
#
#
# Dimensions: 1.89 in x 0.55 in x 0.28 in (4.8 cm x 1.4 cm x 0.7 cm)
# Weight: 0.18 oz (5 g)
#
#
#
#
#
# https://hub360.com.ng/product-category/accessories/
# Male male Jumper wires set
# https://hub360.com.ng/wp-content/uploads/2015/01/37894-1.jpg
# ₦0.00
#
# Keep them together, or split them apart – that’s the beauty of the 20cm (7-3/4″) 40-conductor ribbon jumper with male/female connectors. They behave like any other similar jumper, but these are in a super-convenient ribbon you can easily split apart into custom sets.
#
# 2 way PCB Screw Terminal
# https://hub360.com.ng/wp-content/uploads/2015/05/screw-terminal-1.jpg
# ₦0.00
#
# Features:
#
# Screws: M2.5 Steel Zinc plated
# Wire Guard: Stainless Steel
# Pin Header: Brass, Tin plated
# Housing: PBT, UL94V-0
# Rated voltage: 300V
# Rated current: 16A
# Contact resistance: 20 mΩ
# Insulation resistance: 5000MΩ/DC1000V
# Withstanding voltage: AC1500V/1Min
# Wire range: 24-14AWG 2.5mm2
# Temperature range: -40℃ to +105℃
# Torque: 0.5Nm(3.6lb.in)
# Strip length: 4.5mm to 5.0mm
#
#
# Tact switch
# https://hub360.com.ng/wp-content/uploads/2015/01/tact-switch-1.jpg
# ₦0.00
#
#
#
#
# Feature momentary contact, 4 pins, round black  push button, through hole mounting, 6 x 6 x 5mm size, etc.
# Used in the fields of electronic products,  household appliances and more.
# High precision mechanism design offers acute  operation and long service life. Specification
#
# Size: Approx.6x6x5mm
#
#
#
# Temperature: -25°~+-85°C
# Rated Load: DC12V 0.1A
# Contact Resistance: ≤ 0.03Ω
# Withstand Voltage: AC250 V (50Hz) /MIN
# Actuation Force: 1.3+-0.5N
# Insulation Resistance: ≥100MΩ
# Life:100000 times
#
#
#
#
# 9V battery
# https://hub360.com.ng/wp-content/uploads/2015/01/0J2997.200-1.jpg
# ₦0.00
#
#
# Model Number: 9V 6F 22
# Battery Type: Zinc Carbon
# Size: 6F22 006P
# Jacket: Metal
# Single Battery Dimensions (mm): L- 26. 5, H – 48. 5, W – 17. 5 (Max)
# Nominal Voltage(V) :9V
# Discharge Resistance(Ω): 620
# Cut-off Voltage(V): 5.4
#
#
# Male male jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-3-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# 20w hot glue stick
# https://hub360.com.ng/wp-content/uploads/2017/03/23-1.jpg
# ₦0.00
#
# This Glue Sticks are created with safe and reliable materials which are great for projects, arts and crafts, designing and DIYs. Application for paper, metal, wood, glass, card, fabric, plastic, ceramics and more. It works perfectly on low or high temperature glue guns and always dry clear and secure
#
# Male female jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-2-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# Photoresistor LDR
# https://hub360.com.ng/wp-content/uploads/2015/01/Photoresistor-1.jpg
# ₦0.00
#
# The maximum voltage (V-dc): 150
# Maximum power (mW): 100
# The environment temperature (° C): -30— +70
# The spectral peak (nm): 560
# Bright resistance (10Lux) (K): 5-10
# Dark resistance (M Ω): 0.8
# Response time (MS): the rise of: 30
# Drop: 30
# Illumination resistance characteristics: 2
#
# 9V battery connector
# https://hub360.com.ng/wp-content/uploads/2015/02/battery-connector-1.jpg
# ₦0.00
#
# It is to be connected with 9v battery. it has two wires
#
# Condenser mic 4 5 2 2mm microphone
# https://hub360.com.ng/wp-content/uploads/2015/01/Electret-condenser-microphone-1.jpg
# ₦0.00
#
# This is a parallel plate capacitor and works on the principle of a variable capacitance. It consists of two plates, one fixed (called the back plate) and the other moveable (called Diaphragm) with a small gap between them. An electric potential charges the plate. When sound strikes the diaphragm it starts moving, thereby changing the capacitance between the plates which in turn results in a variable electric current to flow.
#
# VK2828 G28U7FTTL 1 10Hz airplane GPS module
# https://hub360.com.ng/wp-content/uploads/2016/02/VK2828.jpg
# ₦0.00
#
# Highlights:
#
# Product main chip: U-BLOX UBX-G7020-KT Product size: 28x28x8.5mm
# LNA built-in signal amplifier
# Built-in Flash, free configuration of product parameters
# Industry standard 25 x 25 x 4mm high sensitivity ceramic antenna
# Built-in TCXO crystal and farad capacitors to start a warmer start
# 1-10Hz position magnification rate
#
# Technical specifications
#
# Product performance Chip: ublox UBX-G7020-KT
# Frequency: L1, 1575.42MHz
# Baud rate: 4800, 9600, 19200, 38400, 57600, 112500bps
# Channels: 56
# Sensitivity: Tracking: -162dBm, Capture: -160dBm Cold Start -148dBm
# Cold start: average 29 seconds
# Warm start: average 28 seconds
# Hot start: average 1 second
# Accuracy HorizontalPosition: Autonomous <2.5maverage SBAS average <2.0m
# Timepulse signal: RMS 30 ns Maximum height: 50000 meters
# Maximum speed: 500 m / s
# Maximum speed: ≤4G
# Update frequency: 1-10 Hz
# Physical property Dimensions: 28x28X8.5mm
# Work environment Working temperature: -40 ° C to 85 ° C
# Storage temperature: -40 ° C to 85 ° C
#
#
# sg90 servo
# https://hub360.com.ng/wp-content/uploads/2015/01/437144083_782-1.jpg
# ₦0.00
#
#  technical data:
# Size: 21.5 mmX11.8 mmX22.7 mm
# 9 grams of weight:
# No-load speed: 0.12 seconds / 60 degrees (4.8 V)
# Locked-rotor torque: 1.2-1.4 kg/cm (4.8 V)
# Use the temperature: – 30 ~ ~ + 60 degrees Celsius
# Dead zone setting: seven microseconds
# Operating voltage: 4.8 V to 6 V
# Contains: steering gear, rocker arm, screws, etc. All original accessories
#
# 20watts Hot melt glue gun
# https://hub360.com.ng/wp-content/uploads/2017/03/18-1.jpg
# ₦0.00
#
# Hot Melt Easy To Use Multi Purpose 20 watt Glue Gun For Almost All Bonding Jobs Of Any Office And House. Trigger-feed For Even Glue Flow Perfect For Home Repairs, Hobbies And Crafts Lower Temperature For Delicate Materials And Safety Two Finger Trigger For Better Control. Examples Of Usage: Repair Holes In Window Screens Reattach The Float For A Tank After Its Mount Corroded Away Repair Broken Tail Light Covers On Cars Reattach Trim On Cars Reattach The Side View Mirror On A Car Reattach The Heel Of A Shoe Repair The Cracked Housing Of An Electric Appliance Make An Impromptu Model For Your Kids School Project Reattach Plastic Kitchen Cabinet Drawers To Wooden Face Plates Repair Of Toys, Furniture, Tv, Radio, Or Any Plastic Product Body Cracks, Etc. Reattaching Book Binding / Covers Without Stitching. Repair Umbrellas Whose Spines Have Separated From The Material Plug In Gun. Load The Glue Sticks Into The Back Of The Gun. Press Trigger Several Times Until The Glue Stick Is Firmly Set Into The Inlet Tube Allow The Glue Gun To Warm Up For Approx.5 Minutes Squeeze Trigger Until Glue Flows From Nozzle
# Male female jumper wire set
# https://hub360.com.ng/wp-content/uploads/2018/02/1-4-1.jpg
# ₦0.00
#
# This is a set of 40 connected male-female dupont jumper wires. The wires can all be used together or easily peeled apart individually or in sections.
#
# L298N Dual H Bridge DC Stepper Motor Driver
# https://hub360.com.ng/wp-content/uploads/2015/01/L298StepperController__79861.1411263026.1280.1280-1.jpg
# ₦0.00
#
# Basic attributes
# Module name :Dual H-bridge motor driver module
# Operating mode :H-bridge driver (dual)
# Master chip :L298N
# Logic voltage :5V
# Drive voltage :5V-35V
# Logic Current :0mA-36mA
# Drive current :2A (MAX single bridge)
# Storage Temperature :-20 to 135
# Maximum Power :25W
# Weight :30g
# External dimensions :43 * 43 * 27mm
#
# sg90 servo
# https://hub360.com.ng/wp-content/uploads/2015/01/437144083_782-1.jpg
# ₦0.00
#
#  technical data:
# Size: 21.5 mmX11.8 mmX22.7 mm
# 9 grams of weight:
# No-load speed: 0.12 seconds / 60 degrees (4.8 V)
# Locked-rotor torque: 1.2-1.4 kg/cm (4.8 V)
# Use the temperature: – 30 ~ ~ + 60 degrees Celsius
# Dead zone setting: seven microseconds
# Operating voltage: 4.8 V to 6 V
# Contains: steering gear, rocker arm, screws, etc. All original accessories
#
# Male male jumper wire single
# https://hub360.com.ng/wp-content/uploads/2018/02/1-3-1.jpg
# ₦0.00
#
# This is a single piece male-female jumper wires.
#
# Male male Jumper wires set
# https://hub360.com.ng/wp-content/uploads/2015/01/37894-1.jpg
# ₦0.00
#
# Keep them together, or split them apart – that’s the beauty of the 20cm (7-3/4″) 40-conductor ribbon jumper with male/female connectors. They behave like any other similar jumper, but these are in a super-convenient ribbon you can easily split apart into custom sets.
#
# Raspberry Pi 4 Aluminum Case with Dual Cooling Fan Metal Shell
# https://hub360.com.ng/wp-content/uploads/2016/10/heat-sink-casing.jpg
# ₦0.00
#
# Please note that raspberry pi is not included
# Features:
#
# Ultra-thin design
# Easy to install
# Fast Heat dissipation
# Smooth and straight aluminum material
# All ports and slots of the case can match with Raspberry Pi 4 Computer Model B perfectly
# Open case design, you don’t need to worry it will effect wifi signal any more
# Reinforced aluminum material, lightweight and durable, long-lasting stainles
# We use silicon cooling pad (the thickness is only 0.5mm) to touch the shell body to dissipate heat. You can use the CPU grease to relace the silicon colling pad to get better heat dissipation.
#
#
# Dual Fan:
#
#  Noise: 18dB
#  Low Power Consumption Design
#  Dual Cooling Expericnce, More powerful heat dissipation
#  Very Quiet Cooling Fan, get rid of the fan noisy
#  All of the Fans were Tested by Our Engineer, Very Nice Quality Control
#  Update Thermal Tape Can Make Sure Best Heat Conduction Effect
#
#
# 125KHZ RFID Key chain
# https://hub360.com.ng/wp-content/uploads/2015/01/rfid-tag-keychain-1.jpg
# ₦0.00
#
# Features:
#
#
# Size:3.5 x 2.8 x 0.4cm
#
#
# Material: Plastic
#
#
# Operation frequency: 125Khz
#
#
# Detecting distance: 3-10cm
#
#
# Compatible with all Door Entry system
#
#
# Easy to carry
#
#
# Water resistant
#
#
# Each token pre-programmed with unique ID which is printed on it
#
#
# Each comes with Key ring included
#
#
# Compatible with all RFID reader to gain access
#
#
# No external power required.
#
#
# Brand new key inductive card for entrance guard system.
#
#
# It applies to access control, hotel locks, staff attendance and school campus access and payment control, identification and security systems, parking lot entry and payment, social security management, transportation payment, municipal and ancillary service payment.
#
#
#
# 14uH 43mm high current wireless power coil XKT L3
# https://hub360.com.ng/wp-content/uploads/2015/01/XKT-L3.jpg
# ₦0.00
#
# Parameters: the line diameter 1.1mm, the outer diameter 43mm, the inner diameter 20mm single layer thickness 2.3mm, can be applied to the XKT-412 chip.
# Working current 2000mA, this coil is mainly used in wireless charging scheme, this coil is a standard machine.
#
#
#
# 4 4 matrix keypad
# https://hub360.com.ng/wp-content/uploads/2015/01/HT16RnoFRVbXXagOFbX7-1.jpg
# ₦0.00
#
# Contact resistance of 500
# Insulation resistance 100M
# Key Operating Force 150-200N
# Rebound time 1 (ms)
# Life of 100 million (times)
# Operating Temperature 60
#
# 1, the electronic characteristics
# Circuit Rating: 35V (DC), 100mA, 1W
# Contact resistance: 10Ω ~ 500Ω
# (Varies according to the lead lengths and different from those of the material used)
# Insulation resistance: 100MΩ 100V
# Dielectric Strength: 250VRms (50 ~ 60Hz 1min)
# Electric shock jitter: <5ms
# Life span: tactile type: ≥ one million times
#
# 2, the mechanical properties
# Operating pressure: Touch feeling: 170 ~ 397g (6 ~ 14oz)
# Switch travel: touch-type: 0.6 ~ 1.5mm
#
# 3, the environment parameters
# Operating temperature: -40 to +80
# Storage temperature: -40 to +80
# Temperature: from 40,90% to 95%, 240 hours
# Vibration: 20G, max. (10 ~~ 200Hz, the Mil-SLD-202 M204.Condition B)
#
# Raspberry Pi 4 Aluminum Case with Dual Cooling Fan Metal Shell
# https://hub360.com.ng/wp-content/uploads/2016/10/heat-sink-casing.jpg
# ₦0.00
#
# Please note that raspberry pi is not included
# Features:
#
# Ultra-thin design
# Easy to install
# Fast Heat dissipation
# Smooth and straight aluminum material
# All ports and slots of the case can match with Raspberry Pi 4 Computer Model B perfectly
# Open case design, you don’t need to worry it will effect wifi signal any more
# Reinforced aluminum material, lightweight and durable, long-lasting stainles
# We use silicon cooling pad (the thickness is only 0.5mm) to touch the shell body to dissipate heat. You can use the CPU grease to relace the silicon colling pad to get better heat dissipation.
#
#
# Dual Fan:
#
#  Noise: 18dB
#  Low Power Consumption Design
#  Dual Cooling Expericnce, More powerful heat dissipation
#  Very Quiet Cooling Fan, get rid of the fan noisy
#  All of the Fans were Tested by Our Engineer, Very Nice Quality Control
#  Update Thermal Tape Can Make Sure Best Heat Conduction Effect
#
#
# Professional soldering iron 60W
# https://hub360.com.ng/wp-content/uploads/2016/10/131-1.jpg
# ₦0.00
#
#
#
# This High-Quality 100W/220V Soldering Iron is ideal for the electrical and automotive industries. Comes with comfortable rubber coated handle. Continuous rated (24 hours) operates at Maximum Temperature
#
# 125KHZ RFID Card
# https://hub360.com.ng/wp-content/uploads/2015/01/im120808002_1-1.jpg
# ₦0.00
#
# Description:
# White card
# 125KHZ chip material type: EM4100, EM4102, SMC4001, T55567
# Card thickness: 0.8mm±0.03mm
# Distance of reaction:6 -20cm
# Encapsulation materials: PVC. ABS
# Typical application: Timecard,Access Control Card ,enterprise one card system etc.
#
# SMD tact switch with cap
# https://hub360.com.ng/wp-content/uploads/2016/02/IMG_1300-1-scaled.jpg
# ₦0.00
#
# This is a push button. It has four terminals
#
# MG996r Metal Gear Servo
# https://hub360.com.ng/wp-content/uploads/2015/02/servo-mg996r-1.jpg
# ₦0.00
#
# Compliant with most standard receiver connector: Futaba, Hitec, Sanwa, GWS etc…
# Great for truck, Boat, Racing Car, Helicopter and Airplane.
# Power Supply: Through External Adapter.
# Stable and Shock Proof. – Coreless Motor – Metal Gear – Double Ball Bearing – Connector Wire
# Length 300mm
# Dimension : 40.7mm x 19.7mm x 42.9mm
# Weight : 55g
# Operating Speed : 0.17sec / 60 degrees (4.8V no load)
# Operating Speed : 0.14sec / 60 degrees (6.0V no load)
# Stall Torque : 9.4kg/cm(4.8v),11kg/cm(6v)
# Operation Voltage : 4.8 – 7.2Volts
# Gear Type: All Metal Gears
# Connector Wire: Heavy Duty, 11.81″ (300mm)
#
# https://hub360.com.ng/product-category/resistors/
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5044/820493828.py in <module>
#      20             urllib.request.urlretrieve(img, f"{name}.png".replace("*", "x").replace("/", "-"))
#      21
# ---> 22             description = single_products.find("div", {"class":"woocommerce-Tabs-panel woocommerce-Tabs-panel--description panel entry-content wc-tab"}).text
#      23             price = single_products.find("bdi").text
#      24             file_name = name.replace("*", "x").replace("/", "-")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
response = requests.get("https://hub360.com.ng/product-category/accessorie/")

# %%
products = soup(response.text).find_all("div", {"class":"product-block"})

# %%
for product in products:
    data = product.find("h3", {"class":"name"})
    print(data)
# Out:
# <h3 class="name"><a href="https://hub360.com.ng/product/male-male-jumper-wire-single/">Male-male jumper wire (single)</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/20w-hot-glue-stick/">20w hot glue stick</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/male-female-jumper-wire-single/">Male-female jumper wire (single)</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/male-female-jumper-wire-set/">Male-female jumper wire (set)</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/hot-glue-sticks/">Hot glue sticks-60w</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/neodymium-super-magnet/">Neodymium super magnet 8x5mm</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/female-female-jumper-wire-single/">Female-female jumper wire (single)</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/tact-switch-12126/">Tact switch 12*12*6</a></h3>
# <h3 class="name"><a href="https://hub360.com.ng/product/female-female-jumper-wire-set/">Female-female jumper wire (set)</a></h3>

# %%
data

# %%
payload = {
    "contacts":["2347046946265"],
    "sender_id":"2348031346306",
    "message":"Hello here's your OTP - 0 1 0 1 3 3",
    "send_date":"03-09-2021 00:42",
    "campaign_name":"Promotion",
    "voice_speed": 0,
    "voice_gender":"female",
    "voice_url": "false"
}

headers = {
    "Authorization": f"Token 9fbfef0d23935ce7d5e29650d98a2d239ed19537"
}

# %%
requests.post(f"https://whispersms.xyz/whisper/send_voice_message/", json= payload, headers= headers)
# Out:
# <Response [201]>

# %%
1+1
# Out:
# 2
